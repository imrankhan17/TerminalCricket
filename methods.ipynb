# %%
import pandas as pd
pd.options.display.max_columns = 100
from get_dataframe import df

# %%
df
# Out:
#    current_day  current_innings  \
# 0            1                2
# 1            1                1
# 2            2                2
#
#                                        match_summary is_finished  \
# 0  WI Women won by 6 wickets (with 66 balls remai...      Result
# 1         Bangladesh won the toss and elected to bat        Live
# 2  Bangladesh A trail by 91 runs with 7 wickets r...        Live
#
#               full_date                                        description  \
# 0  2017-10-11T13:30:00Z  1st ODI, ICC Women's Championship at Tarouba, ...
# 1  2017-10-12T08:00:00Z  Tour Match, Bangladesh tour of South Africa at...
# 2  2017-10-11T03:30:00Z  Only unofficial Test, Ireland A tour of Bangla...
#
#                end_date match_format  \
# 0  2017-10-12T23:59:00Z          ODI
# 1  2017-10-12T23:59:00Z          ODI
# 2  2017-10-14T23:59:00Z         Test
#
#                                         match_name match_short_name  \
# ...

# %%
df[df.match_format == 'ODI']
# Out:
#    current_day  current_innings  \
# 0            1                2
# 1            1                1
#
#                                        match_summary is_finished  \
# 0  WI Women won by 6 wickets (with 66 balls remai...      Result
# 1         Bangladesh won the toss and elected to bat        Live
#
#               full_date                                        description  \
# 0  2017-10-11T13:30:00Z  1st ODI, ICC Women's Championship at Tarouba, ...
# 1  2017-10-12T08:00:00Z  Tour Match, Bangladesh tour of South Africa at...
#
#                end_date match_format  \
# 0  2017-10-12T23:59:00Z          ODI
# 1  2017-10-12T23:59:00Z          ODI
#
#                                         match_name match_short_name  \
# 0              West Indies Women v Sri Lanka Women      WI-W v SL-W
# 1  Cricket South Africa Invitation XI v Bangladesh    SA-XI v BDESH
#
#   match_title                    tour_abbrev  is_tournament  \
# ...
